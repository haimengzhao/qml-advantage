# %%
import numpy as np
import pandas as pd

# %%
# read csv
df = pd.read_csv('ED.csv', header=None, skiprows=1, index_col=(0, 1))
df1 = pd.read_csv('ED_1.csv', header=None, skiprows=1, index_col=(0, 1))

# %%
df
# Out:
#            2         3      4         5      6         7      8         9   \
# 0  1
# 1  4    0.796  0.024976  0.943  0.014370  1.000  0.000000  0.936  0.015170
#    5    1.000  0.000000  1.000  0.000000  0.776  0.025841  0.939  0.014834
#    6    0.817  0.023966  0.942  0.014488  1.000  0.000000  0.934  0.015389
#    8    1.000  0.000000  1.000  0.000000  0.940  0.014720  1.000  0.000000
#    11   1.000  0.000000  1.000  0.000000  1.000  0.000000  1.000  0.000000
# ...       ...       ...    ...       ...    ...       ...    ...       ...
# 10 184  0.117  0.019922  0.109  0.019316  0.142  0.021634  0.111  0.019470
#    237  0.119  0.020069  0.136  0.021246  0.115  0.019773  0.120  0.020141
#    307  0.120  0.020141  0.119  0.020069  0.109  0.019316  0.131  0.020912
#    396  0.138  0.021377  0.125  0.020498  0.138  0.021377  0.129  0.020776
#    512  0.123  0.020357  0.142  0.021634  0.099  0.018511  0.117  0.019922
#
# ...

# %%
# merge df and df1
df_m = pd.concat([df, df1], axis=1)

# %%
df_m
# Out:
#            2         3      4         5      6         7      8         9   \
# 0  1
# 1  4    0.796  0.024976  0.943  0.014370  1.000  0.000000  0.936  0.015170
#    5    1.000  0.000000  1.000  0.000000  0.776  0.025841  0.939  0.014834
#    6    0.817  0.023966  0.942  0.014488  1.000  0.000000  0.934  0.015389
#    8    1.000  0.000000  1.000  0.000000  0.940  0.014720  1.000  0.000000
#    11   1.000  0.000000  1.000  0.000000  1.000  0.000000  1.000  0.000000
# ...       ...       ...    ...       ...    ...       ...    ...       ...
# 10 184  0.117  0.019922  0.109  0.019316  0.142  0.021634  0.111  0.019470
#    237  0.119  0.020069  0.136  0.021246  0.115  0.019773  0.120  0.020141
#    307  0.120  0.020141  0.119  0.020069  0.109  0.019316  0.131  0.020912
#    396  0.138  0.021377  0.125  0.020498  0.138  0.021377  0.129  0.020776
#    512  0.123  0.020357  0.142  0.021634  0.099  0.018511  0.117  0.019922
#
# ...

# %%
# save to csv
df_m.to_csv('ED_merged.csv', header=False)
