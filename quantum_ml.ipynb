# %%
import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="false"
import jax
import numpy as np
import jax.numpy as jnp
import tensorcircuit as tc
K = tc.set_backend("jax")
from magic_game import bit_to_num
from quantum_model import Quantum_Strategy
from optax import adam
# Out:
# 2024-04-12 23:01:48.607284: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Please first ``pip install -U qiskit`` to enable related functionality in translation module

# %%
key = jax.random.PRNGKey(0)
key, subkey = jax.random.split(key)
weight_A = jax.random.normal(key, (4, 16))
weight_B = jax.random.normal(subkey, (4, 16))
# Out:
# 2024-04-12 23:01:51.100186: W external/xla/xla/service/gpu/nvptx_compiler.cc:742] The NVIDIA driver's CUDA version is 12.0 which is older than the ptxas CUDA version (12.4.99). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %%
# two qubit Pauli basis
I = jnp.array([[1, 0], [0, 1]], dtype=jnp.complex64)
X = jnp.array([[0, 1], [1, 0]], dtype=jnp.complex64)
Y = jnp.array([[0, -1j], [1j, 0]], dtype=jnp.complex64)
Z = jnp.array([[1, 0], [0, -1]], dtype=jnp.complex64)
basis = jnp.array([jnp.kron(a, b) for a in [I, X, Y, Z] for b in [I, X, Y, Z]])
bit_to_op = jnp.array([(I + Z) / 2, (I - Z) / 2])

# %%
def weight_to_hamiltonian(weight):
    return jnp.einsum("i,ijk->jk", weight, basis)

# %%
def get_nll(n, weights_A, weights_B, inputs, targets):
    # n: number of games
    # weights_A: (4, 16)
    # weights_B: (4, 16)
    # inputs: (4 * n,)
    # targets: (4 * n,)
    
    inputs = bit_to_num(inputs.reshape(-1, 2))
    
    c = tc.Circuit(4 * n)
    # Bell state
    for i in range(n):
        c.H(2 * i)
        c.CNOT(2 * i, 2 * n + 2 * i)
        c.H(2 * i + 1)
        c.CNOT(2 * i + 1, 2 * n + 2 * i + 1)
    
    # U(weight)
    for i in range(n):
        c.EXP(2 * i, 2 * i + 1, theta=1, hamiltonian=weight_to_hamiltonian(weights_A[inputs[i]]))
        c.EXP(2 * n + 2 * i, 2 * n + 2 * i + 1, theta=1, hamiltonian=weight_to_hamiltonian(weights_B[inputs[n + i]]))
        
    # measure likelihood
    ops = [(bit_to_op[targets[i]], [i,]) for i in range(len(targets))]
    exp = c.expectation(*ops)
    
    return -jnp.log(jnp.real(exp) + 1e-10)

# %%
def sample(n, weights_A, weights_B, inputs):
    inputs = bit_to_num(inputs.reshape(-1, 2))
    
    c = tc.Circuit(4 * n)
    # Bell state
    for i in range(n):
        c.H(2 * i)
        c.CNOT(2 * i, 2 * n + 2 * i)
        c.H(2 * i + 1)
        c.CNOT(2 * i + 1, 2 * n + 2 * i + 1)
    
    # U(weight)
    for i in range(n):
        c.EXP(2 * i, 2 * i + 1, theta=1, hamiltonian=weight_to_hamiltonian(weights_A[inputs[i]]))
        c.EXP(2 * n + 2 * i, 2 * n + 2 * i + 1, theta=1, hamiltonian=weight_to_hamiltonian(weights_B[inputs[n + i]]))
        
    # sample a bit string
    sample = c.measure(*range(4 * n), with_prob=False)[0]
    
    return sample

sample_vmap = jax.vmap(sample, in_axes=(None, None, None, 0))

# %%
get_nll_vmap = jax.vmap(get_nll, in_axes=(None, None, None, 0, 0), out_axes=0)
get_nll_batch = lambda n, weights_A, weights_B, inputs, targets: jnp.mean(get_nll_vmap(n, weights_A, weights_B, inputs, targets))
grad_nll = jax.grad(get_nll_batch, argnums=(1, 2))

# %%
inputs = jnp.zeros((4,), dtype=jnp.int16)
targets = jnp.array([1, 0, 1, 0], dtype=jnp.int16)
get_nll(1, weight_A, weight_B, inputs, targets)
# Out:
# Array(2.9956663, dtype=float32)

# %%
n = 1
test_size = 10000
data = np.load(f"./data/data_{n}.npz")
data_size = len(data['X'])
x_train = data['X']; y_train = data['Y']
x_test = np.random.randint(0, 2, (test_size, x_train.shape[1]))

# %%
batch_size = 32
n_epochs = 100
n_batches = data_size // batch_size
lr = 1e-2
opt = adam(lr)
opt_state = opt.init((weight_A, weight_B))

for epoch in range(n_epochs):
    for i in range(n_batches):
        x_batch = x_train[i * batch_size: (i + 1) * batch_size]
        y_batch = y_train[i * batch_size: (i + 1) * batch_size]
        grad_A, grad_B = grad_nll(n, weight_A, weight_B, x_batch, y_batch)
        # updates, opt_state = opt.update((grad_A, grad_B), opt_state)
        weight_A = weight_A - lr * grad_A
        weight_B = weight_B - lr * grad_B
        print(f"Epoch {epoch}, batch {i}, loss {get_nll_batch(n, weight_A, weight_B, x_batch, y_batch)}")
# Out:
# Epoch 0, batch 0, loss 3.062504291534424
# Epoch 0, batch 1, loss 2.95979905128479
# Epoch 0, batch 2, loss 3.03666353225708
# Epoch 0, batch 3, loss 3.407806873321533
# Epoch 0, batch 4, loss 3.1409687995910645
# Epoch 0, batch 5, loss 3.285081148147583
# Epoch 0, batch 6, loss 3.2066898345947266
# Epoch 0, batch 7, loss 3.138278007507324
# Epoch 0, batch 8, loss 2.9444949626922607
# Epoch 0, batch 9, loss 3.1234118938446045
# Epoch 0, batch 10, loss 3.202165126800537
# Epoch 0, batch 11, loss 3.304335594177246
# Epoch 0, batch 12, loss 2.9373021125793457
# Epoch 0, batch 13, loss 3.1398775577545166
# Epoch 0, batch 14, loss 3.104675769805908
# Epoch 0, batch 15, loss 3.284898281097412
# Epoch 0, batch 16, loss 2.9489941596984863
# Epoch 0, batch 17, loss 3.228365421295166
# Epoch 0, batch 18, loss 3.0252938270568848
# Epoch 0, batch 19, loss 3.1636557579040527
# Epoch 0, batch 20, loss 3.3313472270965576
# Epoch 0, batch 21, loss 3.441865921020508
# Epoch 0, batch 22, loss 2.8106260299682617
# Epoch 0, batch 23, loss 2.753493309020996
# Epoch 0, batch 24, loss 2.8613219261169434
# Epoch 0, batch 25, loss 3.100783348083496
# Epoch 0, batch 26, loss 3.0145678520202637
# Epoch 0, batch 27, loss 2.7095537185668945
# Epoch 0, batch 28, loss 2.7729287147521973
# Epoch 0, batch 29, loss 3.1637308597564697
# Epoch 0, batch 30, loss 2.75455379486084
# Epoch 0, batch 31, loss 3.0581605434417725
# Epoch 0, batch 32, loss 3.195115566253662
# Epoch 0, batch 33, loss 2.904262065887451
# Epoch 0, batch 34, loss 2.7759616374969482
# Epoch 0, batch 35, loss 3.0399680137634277
# Epoch 0, batch 36, loss 2.9069902896881104
# Epoch 0, batch 37, loss 2.757206916809082
# Epoch 0, batch 38, loss 2.874907970428467
# Epoch 0, batch 39, loss 3.073359966278076
# Epoch 0, batch 40, loss 3.0198488235473633
# Epoch 0, batch 41, loss 3.238743305206299
# Epoch 0, batch 42, loss 2.869436264038086
# Epoch 0, batch 43, loss 2.97633695602417
# Epoch 0, batch 44, loss 2.979062795639038
# Epoch 0, batch 45, loss 3.0921502113342285
# Epoch 0, batch 46, loss 2.8232264518737793
# Epoch 0, batch 47, loss 2.76676082611084
# Epoch 0, batch 48, loss 3.051403522491455
# Epoch 0, batch 49, loss 3.0198442935943604
# Epoch 0, batch 50, loss 2.9467732906341553
# Epoch 0, batch 51, loss 2.6922972202301025
# Epoch 0, batch 52, loss 3.130789279937744
# Epoch 0, batch 53, loss 3.0881505012512207
# Epoch 0, batch 54, loss 3.008411407470703
# Epoch 0, batch 55, loss 3.0539331436157227
# Epoch 0, batch 56, loss 2.783177375793457
# Epoch 0, batch 57, loss 2.859053611755371
# Epoch 0, batch 58, loss 2.931816816329956
# Epoch 0, batch 59, loss 2.773249387741089
# Epoch 0, batch 60, loss 2.8861067295074463
# Epoch 0, batch 61, loss 2.8553309440612793
# Epoch 0, batch 62, loss 2.8620147705078125
# Epoch 0, batch 63, loss 3.0589582920074463
# Epoch 0, batch 64, loss 3.009650707244873
# Epoch 0, batch 65, loss 2.8499298095703125
# Epoch 0, batch 66, loss 2.918958902359009
# Epoch 0, batch 67, loss 2.822007179260254
# Epoch 0, batch 68, loss 2.9256837368011475
# Epoch 0, batch 69, loss 2.9852280616760254
# Epoch 0, batch 70, loss 3.052248954772949
# Epoch 0, batch 71, loss 2.773780107498169
# Epoch 0, batch 72, loss 2.9393792152404785
# Epoch 0, batch 73, loss 2.7098634243011475
# Epoch 0, batch 74, loss 2.7945215702056885
# Epoch 0, batch 75, loss 2.8259782791137695
# Epoch 0, batch 76, loss 2.9203732013702393
# Epoch 0, batch 77, loss 3.0254733562469482
# Epoch 0, batch 78, loss 2.8847403526306152
# Epoch 0, batch 79, loss 3.2095727920532227
# Epoch 0, batch 80, loss 2.889767646789551
# Epoch 0, batch 81, loss 2.950498580932617
# Epoch 0, batch 82, loss 2.9603235721588135
# Epoch 0, batch 83, loss 2.957648754119873
# Epoch 0, batch 84, loss 2.764584541320801
# Epoch 0, batch 85, loss 2.8111279010772705
# Epoch 0, batch 86, loss 2.9425582885742188
# Epoch 0, batch 87, loss 2.800967216491699
# Epoch 0, batch 88, loss 2.9652533531188965
# Epoch 0, batch 89, loss 2.7355806827545166
# Epoch 0, batch 90, loss 2.7186243534088135
# Epoch 0, batch 91, loss 2.695213794708252
# Epoch 0, batch 92, loss 3.010589599609375
# Epoch 0, batch 93, loss 2.928306818008423
# Epoch 0, batch 94, loss 2.9332659244537354
# Epoch 0, batch 95, loss 3.1733899116516113
# Epoch 0, batch 96, loss 2.8658084869384766
# Epoch 0, batch 97, loss 2.8479180335998535
# Epoch 0, batch 98, loss 2.839242696762085
# Epoch 0, batch 99, loss 2.756272792816162
# Epoch 0, batch 100, loss 2.9805188179016113
# Epoch 0, batch 101, loss 2.867617607116699
# Epoch 0, batch 102, loss 2.722135066986084
# Epoch 0, batch 103, loss 2.959765911102295
# Epoch 0, batch 104, loss 2.773125648498535
# Epoch 0, batch 105, loss 2.6480658054351807
# Epoch 0, batch 106, loss 2.845982551574707
# Epoch 0, batch 107, loss 2.5599212646484375
# Epoch 0, batch 108, loss 2.9188411235809326
# Epoch 0, batch 109, loss 3.0385234355926514
# Epoch 0, batch 110, loss 2.620823621749878
# Epoch 0, batch 111, loss 2.7242746353149414
# Epoch 0, batch 112, loss 2.584257125854492
# Epoch 0, batch 113, loss 2.813305377960205
# Epoch 0, batch 114, loss 2.6981201171875
# Epoch 0, batch 115, loss 2.899014472961426
# Epoch 0, batch 116, loss 2.8084163665771484
# Epoch 0, batch 117, loss 2.729501247406006
# Epoch 0, batch 118, loss 2.6448915004730225
# Epoch 0, batch 119, loss 2.9329276084899902
# Epoch 0, batch 120, loss 2.819284200668335
# Epoch 0, batch 121, loss 2.984592914581299
# Epoch 0, batch 122, loss 2.7007482051849365
# Epoch 0, batch 123, loss 2.750337600708008
# Epoch 0, batch 124, loss 2.750887155532837
# Epoch 0, batch 125, loss 2.9872193336486816
# Epoch 0, batch 126, loss 2.7809202671051025
# Epoch 0, batch 127, loss 2.6922850608825684
# Epoch 0, batch 128, loss 2.7887136936187744
# Epoch 0, batch 129, loss 2.8259403705596924
# Epoch 0, batch 130, loss 2.733943462371826
# Epoch 0, batch 131, loss 2.827944278717041
# Epoch 0, batch 132, loss 2.8641316890716553
# Epoch 0, batch 133, loss 2.900942802429199
# Epoch 0, batch 134, loss 2.5422286987304688
# Epoch 0, batch 135, loss 2.9047532081604004
# Epoch 0, batch 136, loss 2.792926788330078
# Epoch 0, batch 137, loss 2.923567295074463
# Epoch 0, batch 138, loss 3.06662654876709
# Epoch 0, batch 139, loss 2.7096080780029297
# Epoch 0, batch 140, loss 2.7028160095214844
# Epoch 0, batch 141, loss 2.7826104164123535
# Epoch 0, batch 142, loss 2.6970925331115723
# Epoch 0, batch 143, loss 2.836137294769287
# Epoch 0, batch 144, loss 2.948483943939209
# Epoch 0, batch 145, loss 2.79183292388916
# Epoch 0, batch 146, loss 2.8399364948272705
# Epoch 0, batch 147, loss 2.6806628704071045
# Epoch 0, batch 148, loss 2.8039982318878174
# Epoch 0, batch 149, loss 2.7416346073150635
# Epoch 0, batch 150, loss 2.6829779148101807
# Epoch 0, batch 151, loss 2.6075477600097656
# Epoch 0, batch 152, loss 2.8384361267089844
# Epoch 0, batch 153, loss 2.8171284198760986
# Epoch 0, batch 154, loss 2.654592752456665
# Epoch 0, batch 155, loss 2.7591495513916016
# Epoch 0, batch 156, loss 2.7898240089416504
# Epoch 0, batch 157, loss 2.776749610900879
# Epoch 0, batch 158, loss 2.724104881286621
# Epoch 0, batch 159, loss 2.686898708343506
# Epoch 0, batch 160, loss 2.504343271255493
# Epoch 0, batch 161, loss 2.5704329013824463
# Epoch 0, batch 162, loss 2.71768856048584
# Epoch 0, batch 163, loss 2.4315435886383057
# Epoch 0, batch 164, loss 2.747936248779297
# Epoch 0, batch 165, loss 2.7370550632476807
# Epoch 0, batch 166, loss 2.7251014709472656
# Epoch 0, batch 167, loss 2.8278987407684326
# Epoch 0, batch 168, loss 2.7420248985290527
# Epoch 0, batch 169, loss 2.6681299209594727
# Epoch 0, batch 170, loss 2.7918503284454346
# Epoch 0, batch 171, loss 2.892108201980591
# Epoch 0, batch 172, loss 2.7537548542022705
# Epoch 0, batch 173, loss 2.821988105773926
# Epoch 0, batch 174, loss 2.6147351264953613
# Epoch 0, batch 175, loss 2.6222524642944336
# Epoch 0, batch 176, loss 2.6734509468078613
# Epoch 0, batch 177, loss 2.972055435180664
# Epoch 0, batch 178, loss 2.667694568634033
# Epoch 0, batch 179, loss 2.675158739089966
# Epoch 0, batch 180, loss 2.6814169883728027
# Epoch 0, batch 181, loss 2.5992298126220703
# Epoch 0, batch 182, loss 2.581867218017578
# Epoch 0, batch 183, loss 2.665142059326172
# Epoch 0, batch 184, loss 2.5828676223754883
# Epoch 0, batch 185, loss 2.681516170501709
# Epoch 0, batch 186, loss 2.7526886463165283
# Epoch 0, batch 187, loss 2.470370054244995
# Epoch 0, batch 188, loss 3.0848889350891113
# Epoch 0, batch 189, loss 2.699371337890625
# Epoch 0, batch 190, loss 2.9378318786621094
# Epoch 0, batch 191, loss 2.731200933456421
# Epoch 0, batch 192, loss 2.8743457794189453
# Epoch 0, batch 193, loss 2.7473225593566895
# Epoch 0, batch 194, loss 2.700674533843994
# Epoch 0, batch 195, loss 2.7379815578460693
# Epoch 0, batch 196, loss 2.8420045375823975
# Epoch 0, batch 197, loss 2.619685173034668
# Epoch 0, batch 198, loss 2.662729263305664
# Epoch 0, batch 199, loss 2.778597593307495
# Epoch 0, batch 200, loss 2.5786750316619873
# Epoch 0, batch 201, loss 2.5070300102233887
# Epoch 0, batch 202, loss 2.7022249698638916
# Epoch 0, batch 203, loss 2.770003318786621
# Epoch 0, batch 204, loss 2.7031266689300537
# Epoch 0, batch 205, loss 2.7945504188537598
# Epoch 0, batch 206, loss 2.685332775115967
# Epoch 0, batch 207, loss 2.636416435241699
# Epoch 0, batch 208, loss 2.7560009956359863
# Epoch 0, batch 209, loss 2.8538923263549805
# Epoch 0, batch 210, loss 2.688458204269409
# Epoch 0, batch 211, loss 2.6790261268615723
# Epoch 0, batch 212, loss 2.8095076084136963
# Epoch 0, batch 213, loss 2.7075138092041016
# Epoch 0, batch 214, loss 2.766773223876953
# Epoch 0, batch 215, loss 2.5806288719177246
# Epoch 0, batch 216, loss 2.709613561630249
# Epoch 0, batch 217, loss 2.7502267360687256
# Epoch 0, batch 218, loss 2.6385068893432617
# Epoch 0, batch 219, loss 2.8558547496795654
# Epoch 0, batch 220, loss 2.679499864578247
# Epoch 0, batch 221, loss 2.7373437881469727
# Epoch 0, batch 222, loss 2.692889928817749
# Epoch 0, batch 223, loss 2.8363475799560547
# Epoch 0, batch 224, loss 2.701606273651123
# Epoch 0, batch 225, loss 2.6875996589660645
# Epoch 0, batch 226, loss 2.741696357727051
# Epoch 0, batch 227, loss 2.7149734497070312
# Epoch 0, batch 228, loss 2.694674015045166
# Epoch 0, batch 229, loss 2.5586838722229004
# Epoch 0, batch 230, loss 2.741107940673828
# Epoch 0, batch 231, loss 2.7616682052612305
# Epoch 0, batch 232, loss 2.5060272216796875
# Epoch 0, batch 233, loss 2.59698748588562
# Epoch 0, batch 234, loss 2.7675371170043945
# Epoch 0, batch 235, loss 2.6428680419921875
# Epoch 0, batch 236, loss 2.6139557361602783
# Epoch 0, batch 237, loss 2.72690749168396
# Epoch 0, batch 238, loss 2.590916872024536
# Epoch 0, batch 239, loss 2.774401903152466
# Epoch 0, batch 240, loss 2.868406295776367
# Epoch 0, batch 241, loss 2.6054134368896484
# Epoch 0, batch 242, loss 2.588428020477295
# Epoch 0, batch 243, loss 2.8193359375
# Epoch 0, batch 244, loss 2.816033363342285
# Epoch 0, batch 245, loss 2.426008939743042
# Epoch 0, batch 246, loss 2.6739354133605957
# Epoch 0, batch 247, loss 2.7132327556610107
# Epoch 0, batch 248, loss 2.7381796836853027
# Epoch 0, batch 249, loss 2.610607862472534
# Epoch 0, batch 250, loss 2.6534690856933594
# Epoch 0, batch 251, loss 2.5237984657287598
# Epoch 0, batch 252, loss 2.7037503719329834
# Epoch 0, batch 253, loss 2.6797642707824707
# Epoch 0, batch 254, loss 2.507387399673462
# Epoch 0, batch 255, loss 2.6067967414855957
# Epoch 0, batch 256, loss 2.6731982231140137
# Epoch 0, batch 257, loss 2.7742719650268555
# Epoch 0, batch 258, loss 2.632478713989258
# Epoch 0, batch 259, loss 2.6793479919433594
# Epoch 0, batch 260, loss 3.0309338569641113
# Epoch 0, batch 261, loss 2.6028237342834473
# Epoch 0, batch 262, loss 2.613463878631592
# Epoch 0, batch 263, loss 2.6072545051574707
# Epoch 0, batch 264, loss 2.67411470413208
# Epoch 0, batch 265, loss 2.746908187866211
# Epoch 0, batch 266, loss 2.668694019317627
# Epoch 0, batch 267, loss 2.86830997467041
# Epoch 0, batch 268, loss 2.5007851123809814
# Epoch 0, batch 269, loss 2.753660202026367
# Epoch 0, batch 270, loss 2.5971624851226807
# Epoch 0, batch 271, loss 2.5059638023376465
# Epoch 0, batch 272, loss 2.533870220184326
# Epoch 0, batch 273, loss 2.4894423484802246
# Epoch 0, batch 274, loss 2.527101516723633
# Epoch 0, batch 275, loss 2.4456582069396973
# Epoch 0, batch 276, loss 2.51810884475708
# Epoch 0, batch 277, loss 2.5956475734710693
# Epoch 0, batch 278, loss 2.56903076171875
# Epoch 0, batch 279, loss 2.6083617210388184
# Epoch 0, batch 280, loss 2.7173852920532227
# Epoch 0, batch 281, loss 2.6296005249023438
# Epoch 0, batch 282, loss 2.612190008163452
# Epoch 0, batch 283, loss 2.5994410514831543
# Epoch 0, batch 284, loss 2.494908332824707
# Epoch 0, batch 285, loss 2.4518814086914062
# Epoch 0, batch 286, loss 2.6138617992401123
# Epoch 0, batch 287, loss 2.490011692047119
# Epoch 0, batch 288, loss 2.5695576667785645
# Epoch 0, batch 289, loss 2.5717506408691406
# Epoch 0, batch 290, loss 2.6435275077819824
# Epoch 0, batch 291, loss 2.663534641265869
# Epoch 0, batch 292, loss 2.7192506790161133
# Epoch 0, batch 293, loss 2.5001041889190674
# Epoch 0, batch 294, loss 2.4904050827026367
# Epoch 0, batch 295, loss 2.4890706539154053
# Epoch 0, batch 296, loss 2.5765302181243896
# Epoch 0, batch 297, loss 2.568203926086426
# Epoch 0, batch 298, loss 2.436631202697754
# Epoch 0, batch 299, loss 2.695431709289551
# Epoch 0, batch 300, loss 2.6236705780029297
# Epoch 0, batch 301, loss 2.5457494258880615
# Epoch 0, batch 302, loss 2.554121494293213
# Epoch 0, batch 303, loss 2.55566668510437
# Epoch 0, batch 304, loss 2.6876444816589355
# Epoch 0, batch 305, loss 2.486318349838257
# Epoch 0, batch 306, loss 2.6371970176696777
# Epoch 0, batch 307, loss 2.5755984783172607
# Epoch 0, batch 308, loss 2.584810256958008
# Epoch 0, batch 309, loss 2.668760299682617
# Epoch 0, batch 310, loss 2.6189725399017334
# Epoch 0, batch 311, loss 2.6338095664978027
# Epoch 1, batch 0, loss 2.541897773742676
# Epoch 1, batch 1, loss 2.603275775909424
# Epoch 1, batch 2, loss 2.503551959991455
# Epoch 1, batch 3, loss 2.7012581825256348
# Epoch 1, batch 4, loss 2.6964778900146484
# Epoch 1, batch 5, loss 2.775607109069824
# Epoch 1, batch 6, loss 2.7297229766845703
# Epoch 1, batch 7, loss 2.5547709465026855
# Epoch 1, batch 8, loss 2.5393929481506348
# Epoch 1, batch 9, loss 2.5000126361846924
# Epoch 1, batch 10, loss 2.641970634460449
# Epoch 1, batch 11, loss 2.6831488609313965
# Epoch 1, batch 12, loss 2.5171051025390625
# Epoch 1, batch 13, loss 2.613537549972534
# Epoch 1, batch 14, loss 2.472642183303833
# Epoch 1, batch 15, loss 2.5807931423187256
# Epoch 1, batch 16, loss 2.657250165939331
# Epoch 1, batch 17, loss 2.6671652793884277
# Epoch 1, batch 18, loss 2.586681604385376
# Epoch 1, batch 19, loss 2.712451457977295
# Epoch 1, batch 20, loss 2.7430548667907715
# Epoch 2, batch 13, loss 2.5229244232177734
# Epoch 2, batch 14, loss 2.3061752319335938
# Epoch 2, batch 15, loss 2.3681771755218506
# Epoch 2, batch 16, loss 2.6061477661132812
# Epoch 2, batch 17, loss 2.5561559200286865
# Epoch 2, batch 18, loss 2.475999116897583
# Epoch 2, batch 19, loss 2.602050304412842
# Epoch 2, batch 20, loss 2.610309362411499
# Epoch 2, batch 21, loss 2.556426525115967
# Epoch 2, batch 22, loss 2.475221633911133
# Epoch 2, batch 23, loss 2.501469135284424
# Epoch 2, batch 24, loss 2.575714588165283
# Epoch 2, batch 25, loss 2.495861530303955
# Epoch 2, batch 26, loss 2.450092077255249
# Epoch 2, batch 27, loss 2.401308059692383
# Epoch 2, batch 28, loss 2.4661669731140137
# Epoch 2, batch 29, loss 2.504526138305664
# Epoch 2, batch 30, loss 2.4016010761260986
# Epoch 2, batch 31, loss 2.5696520805358887
# Epoch 2, batch 32, loss 2.594782590866089
# Epoch 2, batch 33, loss 2.534152030944824
# Epoch 2, batch 34, loss 2.4738245010375977
# Epoch 2, batch 35, loss 2.428405284881592
# Epoch 2, batch 36, loss 2.5579514503479004
# Epoch 2, batch 37, loss 2.299412727355957
# Epoch 2, batch 38, loss 2.40561580657959
# Epoch 2, batch 39, loss 2.473142623901367
# Epoch 2, batch 40, loss 2.498901844024658
# Epoch 2, batch 41, loss 2.5787696838378906
# Epoch 2, batch 42, loss 2.4646146297454834
# Epoch 2, batch 43, loss 2.4435300827026367
# Epoch 2, batch 44, loss 2.5633277893066406
# Epoch 2, batch 45, loss 2.4880528450012207
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 16
#      14 weight_A = weight_A - lr * grad_A
#      15 weight_B = weight_B - lr * grad_B
# ---> 16 print(f"Epoch {epoch}, batch {i}, loss {get_nll_batch(n, weight_A, weight_B, x_batch, y_batch)}")
#
# Cell In[7], line 2, in <lambda>(n, weights_A, weights_B, inputs, targets)
#       1 get_nll_vmap = jax.vmap(get_nll, in_axes=(None, None, None, 0, 0), out_axes=0)
# ----> 2 get_nll_batch = lambda n, weights_A, weights_B, inputs, targets: jnp.mean(get_nll_vmap(n, weights_A, weights_B, inputs, targets))
#       3 grad_nll = jax.grad(get_nll_batch, argnums=(1, 2))
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/api.py:1268, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1265 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1266 axis_size_ = (axis_size if axis_size is not None else
#    1267               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1268 out_flat = batching.batch(
#    1269     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1270     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1271     spmd_axis_name=spmd_axis_name
#    1272 ).call_wrapped(*args_flat)
#    1273 return tree_unflatten(out_tree(), out_flat)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# Cell In[5], line 25, in get_nll(n, weights_A, weights_B, inputs, targets)
#      23 # measure likelihood
#      24 ops = [(bit_to_op[targets[i]], [i,]) for i in range(len(targets))]
# ---> 25 exp = c.expectation(*ops)
#      27 return -jnp.log(jnp.real(exp) + 1e-10)
#
# File ~/miniconda3/lib/python3.9/site-packages/tensorcircuit/circuit.py:849, in Circuit.expectation(self, reuse, enable_lightcone, noise_conf, nmc, status, *ops, **kws)
#     847 if enable_lightcone:
#     848     reuse = False
# --> 849 nodes1 = self.expectation_before(*ops, reuse=reuse)
#     850 if enable_lightcone:
#     851     nodes1 = _full_light_cone_cancel(nodes1)
#
# File ~/miniconda3/lib/python3.9/site-packages/tensorcircuit/basecircuit.py:284, in BaseCircuit.expectation_before(self, reuse, *ops, **kws)
#     282     nodes, newdang = self._copy_state_tensor(reuse=reuse)
#     283 else:
# --> 284     nodes1, edge1 = self._copy_state_tensor(reuse=reuse)
#     285     nodes2, edge2 = self._copy_state_tensor(conj=True, reuse=reuse)
#     286     nodes = nodes1 + nodes2
#
# File ~/miniconda3/lib/python3.9/site-packages/tensorcircuit/basecircuit.py:253, in BaseCircuit._copy_state_tensor(self, conj, reuse)
#     251 if t is None:
#     252     nodes, d_edges = self._copy()
# --> 253     t = contractor(nodes, output_edge_order=d_edges)
#     254     setattr(self, "state_tensor", t)
#     255 ndict, edict = tn.copy([t], conjugate=conj)
#
# File ~/miniconda3/lib/python3.9/site-packages/tensorcircuit/cons.py:650, in custom(nodes, optimizer, memory_limit, output_edge_order, ignore_edge_order, **kws)
#     647 total_size = None
#     648 if kws.get("preprocessing", None):
#     649     # nodes = _full_light_cone_cancel(nodes)
# --> 650     nodes, total_size = _merge_single_gates(nodes)
#     651 if not isinstance(optimizer, list):
#     652     alg = partial(optimizer, memory_limit=memory_limit)
#
# File ~/miniconda3/lib/python3.9/site-packages/tensorcircuit/cons.py:264, in _merge_single_gates(nodes, total_size)
#     262 njs = [i for i, n in enumerate(nodes) if id(n) in [id(e0.node1), id(e0.node2)]]
#     263 qjs = [i for i, n in enumerate(queue) if id(n) in [id(e0.node1), id(e0.node2)]]
# --> 264 new_node = tn.contract(e0)
#     265 total_size += _sizen(new_node)
#     267 logger.debug(
#     268     _sizen(new_node, is_log=True),
#     269 )
#
# File ~/miniconda3/lib/python3.9/site-packages/tensornetwork/network_components.py:2003, in contract(edge, name, axis_names)
#    2001 if edge.node1 is edge.node2:
#    2002     return _contract_trace(edge, name)
# -> 2003 new_tensor = backend.tensordot(
#    2004     edge.node1.tensor, edge.node2.tensor, [[edge.axis1], [edge.axis2]]
#    2005 )
#    2006 new_node = Node(
#    2007     tensor=new_tensor, name=name, axis_names=axis_names, backend=backend.name
#    2008 )
#    2009 # edge.node1 and edge.node2 get new edges in _remove_edges
#
# File ~/miniconda3/lib/python3.9/site-packages/tensornetwork/backends/jax/jax_backend.py:62, in JaxBackend.tensordot(self, a, b, axes)
#      59 def tensordot(
#      60     self, a: Tensor, b: Tensor, axes: Union[int, Sequence[Sequence[int]]]
#      61 ) -> Tensor:
# ---> 62     return jnp.tensordot(a, b, axes, precision=self.jax_precision)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:3458, in tensordot(a, b, axes, precision, preferred_element_type)
#    3456 util.check_arraylike("tensordot", a, b)
#    3457 dtypes.check_user_dtype_supported(preferred_element_type, "tensordot")
# -> 3458 a, b = asarray(a), asarray(b)
#    3459 a_ndim = ndim(a)
#    3460 b_ndim = ndim(b)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:2233, in asarray(a, dtype, order, copy)
#    2231 if dtype is not None:
#    2232   dtype = dtypes.canonicalize_dtype(dtype, allow_extended_dtype=True)  # type: ignore[assignment]
# -> 2233 return array(a, dtype=dtype, copy=bool(copy), order=order)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:2188, in array(object, dtype, copy, order, ndmin)
#    2185 else:
#    2186   raise TypeError(f"Unexpected input type for array: {type(object)}")
# -> 2188 out_array: Array = lax_internal._convert_element_type(
#    2189     out, dtype, weak_type=weak_type)
#    2190 if ndmin > ndim(out_array):
#    2191   out_array = lax.expand_dims(out_array, range(ndmin - ndim(out_array)))
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py:538, in _convert_element_type(operand, new_dtype, weak_type)
#     535   new_dtype = np.dtype(new_dtype)
#     536 new_dtype = dtypes.dtype(new_dtype, canonicalize=True)
# --> 538 if (dtypes.issubdtype(old_dtype, np.complexfloating) and
#     539     not dtypes.issubdtype(new_dtype, np.complexfloating)):
#     540   msg = "Casting complex values to real discards the imaginary part"
#     541   warnings.warn(msg, NumpyComplexWarning, stacklevel=2)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/dtypes.py:357, in issubdtype(a, b)
#     354   a = a.type
#     356 # For all others, normalize inputs to scalar types.
# --> 357 a_sctype = a if _issubclass(a, np.generic) else np.dtype(a).type
#     358 b_sctype = b if _issubclass(b, np.generic) else np.dtype(b).type
#     360 # Now do special handling of custom float and int types, as they don't conform
#     361 # to the normal scalar type hierarchy.
#
# KeyboardInterrupt:

# %%
pred = sample_vmap(n, weight_A, weight_B, x_test)
qs = Quantum_Strategy(n)
check = qs.check_input_output(x_test, pred, flatten=True)
score = np.mean(check)
print(f"Score: {score}")
# Out:
# Score: 0.9393
